# %% [markdown]
# # Sequence to sequence example in Keras (character-level).
#
# Source:
# https://keras.io/examples/lstm_seq2seq/
#
# References:
# - https://arxiv.org/abs/1409.3215
# - https://arxiv.org/abs/1406.1078
#
# This script demonstrates how to implement a basic character-level sequence-to-sequence model. We apply it to translating short English sentences into short Polish sentences, character-by-character. Note that it is fairly unusual to do character-level machine translation, as word-level models are more common in this domain.

# %% [markdown]
# ### Data download
#
# Lots of neat sentence pairs datasets. http://www.manythings.org/anki/

# %%
from __future__ import print_function

import tensorflow.keras as keras
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
import numpy as np

batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = 'pol.txt'

# %% [markdown]
# Let's read the sentences (input = English, target = Polish),
# and extract the character sets for each language.
#
# Target sequences get additional "start sequence" and "end sequence" characters.

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text, ignore = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 73
# Number of unique output tokens: 92
# Max sequence length for inputs: 22
# Max sequence length for outputs: 58

# %% [markdown]
# Make character-to-index dictionaries
# and prepare one-hot-encoding of the whole training input data.
# Note that the sequences are zero-(post)padded to have all equal lengths.

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    encoder_input_data[i, t + 1:, input_token_index[' ']] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.
    decoder_input_data[i, t + 1:, target_token_index[' ']] = 1.
    decoder_target_data[i, t:, target_token_index[' ']] = 1.

# %% [markdown]
# - We start with input sequences from a domain (e.g. English sentences) and corresponding target sequences from another domain (e.g. Polish sentences).
# - An encoder LSTM turns input sequences to 2 state vectors (we keep the last LSTM state and discard the outputs).

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# %% [markdown]
# A decoder LSTM is trained to turn the target sequences into the same sequence but offset by one timestep in the future, a training process called "teacher forcing" in this context. It uses as initial state the state vectors from the encoder. Effectively, the decoder learns to generate `targets[t+1...]` given `targets[...t]`, conditioned on the input sequence.

# %%
# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy',
              metrics=['accuracy'])
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Save model
model.save('s2s.h5')
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
# 8000/8000 [==============================] - 17s 2ms/sample - loss: 1.3158 - accuracy: 0.7048 - val_loss: 1.2977 - val_accuracy: 0.6538
# Epoch 2/100
#  - ETA: 2s - loss: 1.0539 - accuracy: 0.7224
# Epoch 3/100
# 8000/8000 [==============================] - 3s 407us/sample - loss: 0.7863 - accuracy: 0.7872 - val_loss: 0.9374 - val_accuracy: 0.7358
# Epoch 4/100
# 8000/8000 [==============================] - 3s 386us/sample - loss: 0.7053 - accuracy: 0.8025 - val_loss: 0.8495 - val_accuracy: 0.7577
# Epoch 5/100
# 8000/8000 [==============================] - 3s 386us/sample - loss: 0.6518 - accuracy: 0.8148 - val_loss: 0.8272 - val_accuracy: 0.7599
# Epoch 6/100
# 8000/8000 [==============================] - 3s 383us/sample - loss: 0.6213 - accuracy: 0.8212 - val_loss: 0.7857 - val_accuracy: 0.7725
# Epoch 7/100
# 8000/8000 [==============================] - 3s 394us/sample - loss: 0.5929 - accuracy: 0.8287 - val_loss: 0.7634 - val_accuracy: 0.7776
# Epoch 8/100
# 8000/8000 [==============================] - 3s 395us/sample - loss: 0.5671 - accuracy: 0.8356 - val_loss: 0.7394 - val_accuracy: 0.7862
# Epoch 9/100
# 8000/8000 [==============================] - 3s 389us/sample - loss: 0.5440 - accuracy: 0.8428 - val_loss: 0.7174 - val_accuracy: 0.7915
# Epoch 10/100
# 8000/8000 [==============================] - 3s 393us/sample - loss: 0.5231 - accuracy: 0.8486 - val_loss: 0.6950 - val_accuracy: 0.7985
# Epoch 11/100
# 8000/8000 [==============================] - 3s 403us/sample - loss: 0.5040 - accuracy: 0.8544 - val_loss: 0.6756 - val_accuracy: 0.8047
# Epoch 12/100
# 8000/8000 [==============================] - 3s 391us/sample - loss: 0.4862 - accuracy: 0.8591 - val_loss: 0.6674 - val_accuracy: 0.8064
# Epoch 13/100
# 8000/8000 [==============================] - 3s 390us/sample - loss: 0.4695 - accuracy: 0.8641 - val_loss: 0.6542 - val_accuracy: 0.8107
# Epoch 14/100
# 8000/8000 [==============================] - 3s 392us/sample - loss: 0.4546 - accuracy: 0.8685 - val_loss: 0.6332 - val_accuracy: 0.8183
# Epoch 15/100
# 8000/8000 [==============================] - 3s 403us/sample - loss: 0.4397 - accuracy: 0.8726 - val_loss: 0.6260 - val_accuracy: 0.8206
# Epoch 16/100
# 8000/8000 [==============================] - 3s 400us/sample - loss: 0.4260 - accuracy: 0.8764 - val_loss: 0.6181 - val_accuracy: 0.8220
# Epoch 17/100
# 8000/8000 [==============================] - 3s 398us/sample - loss: 0.4132 - accuracy: 0.8803 - val_loss: 0.6105 - val_accuracy: 0.8243
# Epoch 18/100
# 8000/8000 [==============================] - 3s 413us/sample - loss: 0.4009 - accuracy: 0.8838 - val_loss: 0.6114 - val_accuracy: 0.8254
# Epoch 19/100
# 8000/8000 [==============================] - 3s 405us/sample - loss: 0.3890 - accuracy: 0.8872 - val_loss: 0.6081 - val_accuracy: 0.8270
# Epoch 20/100
# 8000/8000 [==============================] - 3s 402us/sample - loss: 0.3780 - accuracy: 0.8903 - val_loss: 0.5993 - val_accuracy: 0.8289
# Epoch 21/100
# 8000/8000 [==============================] - 3s 400us/sample - loss: 0.3672 - accuracy: 0.8936 - val_loss: 0.5945 - val_accuracy: 0.8304
# Epoch 22/100
# 8000/8000 [==============================] - 3s 404us/sample - loss: 0.3566 - accuracy: 0.8967 - val_loss: 0.5933 - val_accuracy: 0.8315
# Epoch 23/100
# 8000/8000 [==============================] - 3s 400us/sample - loss: 0.3471 - accuracy: 0.8992 - val_loss: 0.5974 - val_accuracy: 0.8303
# Epoch 24/100
# 8000/8000 [==============================] - 3s 360us/sample - loss: 0.3377 - accuracy: 0.9021 - val_loss: 0.5915 - val_accuracy: 0.8336
# Epoch 25/100
# 8000/8000 [==============================] - 3s 339us/sample - loss: 0.3281 - accuracy: 0.9049 - val_loss: 0.5995 - val_accuracy: 0.8317
# Epoch 26/100
# 8000/8000 [==============================] - 3s 395us/sample - loss: 0.3192 - accuracy: 0.9074 - val_loss: 0.5965 - val_accuracy: 0.8342
# Epoch 27/100
# 8000/8000 [==============================] - 3s 404us/sample - loss: 0.3107 - accuracy: 0.9100 - val_loss: 0.5992 - val_accuracy: 0.8332
# Epoch 28/100
# 8000/8000 [==============================] - 3s 388us/sample - loss: 0.3024 - accuracy: 0.9125 - val_loss: 0.5991 - val_accuracy: 0.8339
# Epoch 29/100
# 8000/8000 [==============================] - 3s 403us/sample - loss: 0.2942 - accuracy: 0.9149 - val_loss: 0.6052 - val_accuracy: 0.8338
# Epoch 30/100
# 8000/8000 [==============================] - 3s 396us/sample - loss: 0.2859 - accuracy: 0.9172 - val_loss: 0.6097 - val_accuracy: 0.8342
# Epoch 31/100
# 8000/8000 [==============================] - 3s 391us/sample - loss: 0.2789 - accuracy: 0.9195 - val_loss: 0.6108 - val_accuracy: 0.8337
# Epoch 32/100
# 8000/8000 [==============================] - 3s 381us/sample - loss: 0.2714 - accuracy: 0.9216 - val_loss: 0.6137 - val_accuracy: 0.8341
# Epoch 33/100
# 8000/8000 [==============================] - 3s 376us/sample - loss: 0.2643 - accuracy: 0.9237 - val_loss: 0.6196 - val_accuracy: 0.8338
# Epoch 34/100
# 8000/8000 [==============================] - 3s 385us/sample - loss: 0.2569 - accuracy: 0.9257 - val_loss: 0.6237 - val_accuracy: 0.8328
# Epoch 35/100
# 8000/8000 [==============================] - 3s 403us/sample - loss: 0.2505 - accuracy: 0.9279 - val_loss: 0.6289 - val_accuracy: 0.8336
# Epoch 36/100
# 8000/8000 [==============================] - 3s 382us/sample - loss: 0.2437 - accuracy: 0.9295 - val_loss: 0.6356 - val_accuracy: 0.8336
# Epoch 37/100
# 8000/8000 [==============================] - 3s 376us/sample - loss: 0.2374 - accuracy: 0.9314 - val_loss: 0.6433 - val_accuracy: 0.8331
# Epoch 38/100
# 8000/8000 [==============================] - 3s 381us/sample - loss: 0.2310 - accuracy: 0.9334 - val_loss: 0.6491 - val_accuracy: 0.8320
# Epoch 39/100
# 8000/8000 [==============================] - 3s 379us/sample - loss: 0.2251 - accuracy: 0.9351 - val_loss: 0.6534 - val_accuracy: 0.8336
# Epoch 40/100
# 8000/8000 [==============================] - 3s 384us/sample - loss: 0.2192 - accuracy: 0.9370 - val_loss: 0.6597 - val_accuracy: 0.8325
# Epoch 41/100
# 8000/8000 [==============================] - 3s 383us/sample - loss: 0.2139 - accuracy: 0.9384 - val_loss: 0.6688 - val_accuracy: 0.8316
# Epoch 42/100
# 8000/8000 [==============================] - 3s 381us/sample - loss: 0.2081 - accuracy: 0.9401 - val_loss: 0.6713 - val_accuracy: 0.8313
# Epoch 43/100
# 8000/8000 [==============================] - 3s 382us/sample - loss: 0.2034 - accuracy: 0.9415 - val_loss: 0.6785 - val_accuracy: 0.8328
# Epoch 44/100
# 8000/8000 [==============================] - 3s 374us/sample - loss: 0.1977 - accuracy: 0.9433 - val_loss: 0.6890 - val_accuracy: 0.8307
# Epoch 45/100
# 8000/8000 [==============================] - 3s 376us/sample - loss: 0.1930 - accuracy: 0.9447 - val_loss: 0.6999 - val_accuracy: 0.8303
# Epoch 46/100
# 8000/8000 [==============================] - 3s 370us/sample - loss: 0.1885 - accuracy: 0.9459 - val_loss: 0.6973 - val_accuracy: 0.8307
# Epoch 47/100
# 8000/8000 [==============================] - 3s 378us/sample - loss: 0.1834 - accuracy: 0.9473 - val_loss: 0.7053 - val_accuracy: 0.8306
# Epoch 48/100
# 8000/8000 [==============================] - 3s 374us/sample - loss: 0.1790 - accuracy: 0.9488 - val_loss: 0.7146 - val_accuracy: 0.8306
# Epoch 49/100
# 8000/8000 [==============================] - 3s 371us/sample - loss: 0.1746 - accuracy: 0.9501 - val_loss: 0.7273 - val_accuracy: 0.8295
# Epoch 50/100
# 8000/8000 [==============================] - 3s 370us/sample - loss: 0.1704 - accuracy: 0.9514 - val_loss: 0.7316 - val_accuracy: 0.8280
# Epoch 51/100
# 8000/8000 [==============================] - 3s 375us/sample - loss: 0.1663 - accuracy: 0.9525 - val_loss: 0.7343 - val_accuracy: 0.8293
# Epoch 52/100
# 8000/8000 [==============================] - 3s 381us/sample - loss: 0.1621 - accuracy: 0.9538 - val_loss: 0.7503 - val_accuracy: 0.8275
# Epoch 53/100
#  - ETA: 2s - loss: 0.1536 - accuracy: 0.9571
# Epoch 54/100
# 8000/8000 [==============================] - 3s 379us/sample - loss: 0.1546 - accuracy: 0.9559 - val_loss: 0.7633 - val_accuracy: 0.8275
# Epoch 55/100
# 8000/8000 [==============================] - 3s 384us/sample - loss: 0.1506 - accuracy: 0.9571 - val_loss: 0.7630 - val_accuracy: 0.8282
# Epoch 56/100
# 8000/8000 [==============================] - 3s 385us/sample - loss: 0.1477 - accuracy: 0.9579 - val_loss: 0.7712 - val_accuracy: 0.8280
# Epoch 57/100
# 8000/8000 [==============================] - 3s 374us/sample - loss: 0.1442 - accuracy: 0.9590 - val_loss: 0.7794 - val_accuracy: 0.8278
# Epoch 58/100
# 8000/8000 [==============================] - 3s 370us/sample - loss: 0.1409 - accuracy: 0.9600 - val_loss: 0.7848 - val_accuracy: 0.8281
# Epoch 59/100
# 8000/8000 [==============================] - 3s 378us/sample - loss: 0.1373 - accuracy: 0.9610 - val_loss: 0.7977 - val_accuracy: 0.8275
# Epoch 60/100
# 8000/8000 [==============================] - 3s 368us/sample - loss: 0.1344 - accuracy: 0.9618 - val_loss: 0.8059 - val_accuracy: 0.8267
# Epoch 61/100
# 8000/8000 [==============================] - 3s 366us/sample - loss: 0.1317 - accuracy: 0.9628 - val_loss: 0.8073 - val_accuracy: 0.8270
# Epoch 62/100
# 8000/8000 [==============================] - 3s 366us/sample - loss: 0.1288 - accuracy: 0.9634 - val_loss: 0.8157 - val_accuracy: 0.8272
# Epoch 63/100
# 8000/8000 [==============================] - 3s 367us/sample - loss: 0.1256 - accuracy: 0.9644 - val_loss: 0.8245 - val_accuracy: 0.8272
# Epoch 64/100
# 8000/8000 [==============================] - 3s 366us/sample - loss: 0.1229 - accuracy: 0.9652 - val_loss: 0.8317 - val_accuracy: 0.8269
# Epoch 65/100
# 8000/8000 [==============================] - 3s 369us/sample - loss: 0.1203 - accuracy: 0.9658 - val_loss: 0.8428 - val_accuracy: 0.8252
# Epoch 66/100
# 8000/8000 [==============================] - 3s 366us/sample - loss: 0.1174 - accuracy: 0.9665 - val_loss: 0.8488 - val_accuracy: 0.8255
# Epoch 67/100
# 8000/8000 [==============================] - 3s 359us/sample - loss: 0.1157 - accuracy: 0.9671 - val_loss: 0.8509 - val_accuracy: 0.8269
# Epoch 68/100
# 8000/8000 [==============================] - 3s 361us/sample - loss: 0.1124 - accuracy: 0.9682 - val_loss: 0.8589 - val_accuracy: 0.8265
# Epoch 69/100
# 8000/8000 [==============================] - 3s 352us/sample - loss: 0.1106 - accuracy: 0.9687 - val_loss: 0.8660 - val_accuracy: 0.8263
# Epoch 70/100
# 8000/8000 [==============================] - 3s 362us/sample - loss: 0.1077 - accuracy: 0.9693 - val_loss: 0.8748 - val_accuracy: 0.8259
# Epoch 71/100
# 8000/8000 [==============================] - 3s 371us/sample - loss: 0.1057 - accuracy: 0.9701 - val_loss: 0.8809 - val_accuracy: 0.8261
# Epoch 72/100
# 8000/8000 [==============================] - 3s 362us/sample - loss: 0.1033 - accuracy: 0.9710 - val_loss: 0.8909 - val_accuracy: 0.8257
# Epoch 73/100
# 8000/8000 [==============================] - 3s 363us/sample - loss: 0.1017 - accuracy: 0.9711 - val_loss: 0.8951 - val_accuracy: 0.8264
# Epoch 74/100
# 8000/8000 [==============================] - 3s 361us/sample - loss: 0.0993 - accuracy: 0.9718 - val_loss: 0.9026 - val_accuracy: 0.8246
# Epoch 75/100
# 8000/8000 [==============================] - 3s 358us/sample - loss: 0.0970 - accuracy: 0.9724 - val_loss: 0.9085 - val_accuracy: 0.8252
# Epoch 76/100
# 8000/8000 [==============================] - 3s 369us/sample - loss: 0.0949 - accuracy: 0.9732 - val_loss: 0.9179 - val_accuracy: 0.8255
# Epoch 77/100
# 8000/8000 [==============================] - 3s 393us/sample - loss: 0.0938 - accuracy: 0.9734 - val_loss: 0.9255 - val_accuracy: 0.8251
# Epoch 78/100
# 8000/8000 [==============================] - 3s 382us/sample - loss: 0.0915 - accuracy: 0.9740 - val_loss: 0.9252 - val_accuracy: 0.8257
# Epoch 79/100
# 8000/8000 [==============================] - 3s 363us/sample - loss: 0.0898 - accuracy: 0.9746 - val_loss: 0.9368 - val_accuracy: 0.8249
# Epoch 80/100
# 8000/8000 [==============================] - 3s 357us/sample - loss: 0.0880 - accuracy: 0.9752 - val_loss: 0.9419 - val_accuracy: 0.8248
# Epoch 81/100
# 8000/8000 [==============================] - 3s 362us/sample - loss: 0.0863 - accuracy: 0.9754 - val_loss: 0.9448 - val_accuracy: 0.8255
# Epoch 82/100
# 8000/8000 [==============================] - 3s 360us/sample - loss: 0.0841 - accuracy: 0.9762 - val_loss: 0.9542 - val_accuracy: 0.8248
# Epoch 83/100
# 8000/8000 [==============================] - 3s 348us/sample - loss: 0.0829 - accuracy: 0.9765 - val_loss: 0.9547 - val_accuracy: 0.8246
# Epoch 84/100
# 8000/8000 [==============================] - 3s 349us/sample - loss: 0.0813 - accuracy: 0.9771 - val_loss: 0.9629 - val_accuracy: 0.8238
# Epoch 85/100
# 8000/8000 [==============================] - 3s 363us/sample - loss: 0.0795 - accuracy: 0.9774 - val_loss: 0.9698 - val_accuracy: 0.8235
# Epoch 86/100
# 8000/8000 [==============================] - 3s 371us/sample - loss: 0.0784 - accuracy: 0.9775 - val_loss: 0.9751 - val_accuracy: 0.8238
# Epoch 87/100
# 8000/8000 [==============================] - 3s 365us/sample - loss: 0.0766 - accuracy: 0.9783 - val_loss: 0.9857 - val_accuracy: 0.8231
# Epoch 88/100
# 8000/8000 [==============================] - 3s 374us/sample - loss: 0.0751 - accuracy: 0.9787 - val_loss: 0.9900 - val_accuracy: 0.8244
# Epoch 89/100
# 8000/8000 [==============================] - 3s 375us/sample - loss: 0.0739 - accuracy: 0.9789 - val_loss: 0.9968 - val_accuracy: 0.8236
# Epoch 90/100
# 8000/8000 [==============================] - 3s 353us/sample - loss: 0.0722 - accuracy: 0.9794 - val_loss: 1.0059 - val_accuracy: 0.8237
# Epoch 91/100
# 8000/8000 [==============================] - 3s 359us/sample - loss: 0.0706 - accuracy: 0.9802 - val_loss: 1.0110 - val_accuracy: 0.8231
# Epoch 92/100
# 8000/8000 [==============================] - 3s 360us/sample - loss: 0.0693 - accuracy: 0.9803 - val_loss: 1.0129 - val_accuracy: 0.8232
# Epoch 93/100
# 8000/8000 [==============================] - 3s 370us/sample - loss: 0.0683 - accuracy: 0.9806 - val_loss: 1.0235 - val_accuracy: 0.8235
# Epoch 94/100
# 8000/8000 [==============================] - 4s 441us/sample - loss: 0.0667 - accuracy: 0.9811 - val_loss: 1.0244 - val_accuracy: 0.8230
# Epoch 95/100
# 8000/8000 [==============================] - 3s 434us/sample - loss: 0.0652 - accuracy: 0.9817 - val_loss: 1.0318 - val_accuracy: 0.8226
# Epoch 96/100
# 8000/8000 [==============================] - 4s 459us/sample - loss: 0.0647 - accuracy: 0.9815 - val_loss: 1.0342 - val_accuracy: 0.8236
# Epoch 97/100
# 8000/8000 [==============================] - 4s 443us/sample - loss: 0.0632 - accuracy: 0.9819 - val_loss: 1.0501 - val_accuracy: 0.8221
# Epoch 98/100
# 8000/8000 [==============================] - 4s 447us/sample - loss: 0.0621 - accuracy: 0.9825 - val_loss: 1.0448 - val_accuracy: 0.8247
# Epoch 99/100
# 8000/8000 [==============================] - 4s 451us/sample - loss: 0.0611 - accuracy: 0.9825 - val_loss: 1.0553 - val_accuracy: 0.8228
# Epoch 100/100
# 8000/8000 [==============================] - 3s 427us/sample - loss: 0.0597 - accuracy: 0.9831 - val_loss: 1.0595 - val_accuracy: 0.8223

# %% [markdown]
# In inference mode, when we want to decode unknown input sequences, we:
# - Encode the input sequence into state vectors and retrieve initial decoder state
# - Start with a target sequence of size 1 (just the start-of-sequence character)
# - Feed the state vectors and 1-char target sequence to the decoder to produce predictions for the next character
# - Sample the next character using these predictions (we simply use argmax).
# - Append the sampled character to the target sequence
# - Repeat until we generate the end-of-sequence character or we hit the character limit.

# %%
# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: Idź.
#
# -
# Input sentence: Hi.
# Decoded sentence: Cześć.
#
# -
# Input sentence: Run!
# Decoded sentence: Uciekaj!
#
# -
# Input sentence: Run.
# Decoded sentence: Biegnij.
#
# -
# Input sentence: Run.
# Decoded sentence: Biegnij.
#
# -
# Input sentence: Who?
# Decoded sentence: Kto?
#
# -
# Input sentence: Wow!
# Decoded sentence: O, dziamdzia zaprzała jej szadź.
#
# -
# Input sentence: Wow!
# Decoded sentence: O, dziamdzia zaprzała jej szadź.
#
# -
# Input sentence: Help!
# Decoded sentence: Pomocy!
#
# -
# Input sentence: Jump.
# Decoded sentence: Skok.
#
# -
# Input sentence: Stop!
# Decoded sentence: Zatrzymaj się!
#
# -
# Input sentence: Stop!
# Decoded sentence: Zatrzymaj się!
#
# -
# Input sentence: Begin.
# Decoded sentence: Zaczynajcie.
#
# -
# Input sentence: Begin.
# Decoded sentence: Zaczynajcie.
#
# -
# Input sentence: Hello!
# Decoded sentence: Cześć.
#
# -
# Input sentence: Hurry!
# Decoded sentence: Pośpiesz się!
#
# -
# Input sentence: I see.
# Decoded sentence: Widzę.
#
# -
# Input sentence: I see.
# Decoded sentence: Widzę.
#
# -
# Input sentence: I try.
# Decoded sentence: Próbuje słyteś.
#
# -
# Input sentence: I won!
# Decoded sentence: Wygrałem!
#
# -
# Input sentence: Oh no!
# Decoded sentence: O nie!
#
# -
# Input sentence: Relax.
# Decoded sentence: Wyluzuj.
#
# -
# Input sentence: Smile.
# Decoded sentence: Uśmiech.
#
# -
# Input sentence: Attack!
# Decoded sentence: Atak!
#
# -
# Input sentence: Cheers!
# Decoded sentence: Twoje zdrowie!
#
# -
# Input sentence: Cheers!
# Decoded sentence: Twoje zdrowie!
#
# -
# Input sentence: Get up.
# Decoded sentence: Wstawaj to.
#
# -
# Input sentence: Go now.
# Decoded sentence: Idź już.
#
# -
# Input sentence: Got it?
# Decoded sentence: Kapujesz?
#
# -
# Input sentence: Got it?
# Decoded sentence: Kapujesz?
#
# -
# Input sentence: He ran.
# Decoded sentence: On pobiegł.
#
# -
# Input sentence: Hop in.
# Decoded sentence: Wskakuj.
#
# -
# Input sentence: Hug me.
# Decoded sentence: Przytul mnie.
#
# -
# Input sentence: I fell.
# Decoded sentence: Przewróciłam się.
#
# -
# Input sentence: I know.
# Decoded sentence: Wiem.
#
# -
# Input sentence: I quit.
# Decoded sentence: Wychodzę.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: Jedzem ostrymię.
#
# -
# Input sentence: Listen.
# Decoded sentence: Słuchaj.
#
# -
# Input sentence: No way!
# Decoded sentence: Nie mam mowy!
#
# -
# Input sentence: Really?
# Decoded sentence: Naprawdę?
#
# -
# Input sentence: Thanks.
# Decoded sentence: Dziękuję!
#
# -
# Input sentence: Thanks.
# Decoded sentence: Dziękuję!
#
# -
# Input sentence: We try.
# Decoded sentence: Próbujemy.
#
# -
# Input sentence: Why me?
# Decoded sentence: Dlaczego ja?
#
# -
# Input sentence: Ask Tom.
# Decoded sentence: Zapytaj Toma.
#
# -
# Input sentence: Ask Tom.
# Decoded sentence: Zapytaj Toma.
#
# -
# Input sentence: Awesome!
# Decoded sentence: Jesteśmy chorzać.
#
# -
# Input sentence: Be calm.
# Decoded sentence: Bądź spokojny.
#
# -
# Input sentence: Be cool.
# Decoded sentence: Być luzakiem.
#
# -
# Input sentence: Be fair.
# Decoded sentence: Bądź uczciwy.
#
# -
# Input sentence: Be kind.
# Decoded sentence: Bądź miły.
#
# -
# Input sentence: Be nice.
# Decoded sentence: Bądź miły.
#
# -
# Input sentence: Beat it.
# Decoded sentence: Spadaj.
#
# -
# Input sentence: Call me.
# Decoded sentence: Zadzwoń do mnie.
#
# -
# Input sentence: Call us.
# Decoded sentence: Zadzwoń do nas.
#
# -
# Input sentence: Come on!
# Decoded sentence: No chodź.
#
# -
# Input sentence: Come on!
# Decoded sentence: No chodź.
#
# -
# Input sentence: Come on.
# Decoded sentence: No chodź.
#
# -
# Input sentence: Drop it!
# Decoded sentence: Rzuć to!
#
# -
# Input sentence: Get Tom.
# Decoded sentence: Wybiedz onóc.
#
# -
# Input sentence: Get out!
# Decoded sentence: Wynoś się!
#
# -
# Input sentence: Go away!
# Decoded sentence: Idź stąd.
#
# -
# Input sentence: Go away.
# Decoded sentence: Idź sobie.
#
# -
# Input sentence: Go away.
# Decoded sentence: Idź sobie.
#
# -
# Input sentence: Go home.
# Decoded sentence: Idź do domu.
#
# -
# Input sentence: Hang on.
# Decoded sentence: Wytrzymać.
#
# -
# Input sentence: He runs.
# Decoded sentence: On biega.
#
# -
# Input sentence: Help me!
# Decoded sentence: Pomóż mi!
#
# -
# Input sentence: Help me.
# Decoded sentence: Pomóż mi.
#
# -
# Input sentence: Hi, Tom.
# Decoded sentence: Cześć, Tom.
#
# -
# Input sentence: Hit Tom.
# Decoded sentence: Uderz Toma.
#
# -
# Input sentence: Hold it!
# Decoded sentence: Zaczynaj się.
#
# -
# Input sentence: Hug Tom.
# Decoded sentence: Przytul Toma.
#
# -
# Input sentence: I bowed.
# Decoded sentence: Ukłoniłem się.
#
# -
# Input sentence: I tried.
# Decoded sentence: Próbowałem.
#
# -
# Input sentence: I'll go.
# Decoded sentence: Ja pójdę.
#
# -
# Input sentence: I'm Tom.
# Decoded sentence: Jestem sprawiedziwy.
#
# -
# Input sentence: I'm old.
# Decoded sentence: Jestem stary.
#
# -
# Input sentence: I'm sad.
# Decoded sentence: Jestem smutny.
#
# -
# Input sentence: I'm shy.
# Decoded sentence: Jestem nieśmiały.
#
# -
# Input sentence: I'm shy.
# Decoded sentence: Jestem nieśmiały.
#
# -
# Input sentence: It's me!
# Decoded sentence: To ja.
#
# -
# Input sentence: It's me!
# Decoded sentence: To ja.
#
# -
# Input sentence: Keep it.
# Decoded sentence: Zatrzymać to.
#
# -
# Input sentence: Kiss me.
# Decoded sentence: Pocałuj mnie.
#
# -
# Input sentence: Me, too.
# Decoded sentence: Ja także.
#
# -
# Input sentence: Me, too.
# Decoded sentence: Ja także.
#
# -
# Input sentence: Open up.
# Decoded sentence: Otwierać.
#
# -
# Input sentence: Perfect!
# Decoded sentence: Doskonale!
#
# -
# Input sentence: Show me.
# Decoded sentence: Pokaż mi.
#
# -
# Input sentence: Shut up!
# Decoded sentence: Zamknij się!
#
# -
# Input sentence: Stop it.
# Decoded sentence: Zatrzymaj się Tom.
#
# -
# Input sentence: Take it.
# Decoded sentence: Weź to.
#
# -
# Input sentence: Tell me.
# Decoded sentence: Powiedz mi.
#
# -
# Input sentence: Tom ate.
# Decoded sentence: Tom zapłacił.
#
# -
# Input sentence: Tom ran.
# Decoded sentence: Tom biegał.
#
# -
# Input sentence: Wake up!
# Decoded sentence: Obudź się!
#
# -
# Input sentence: Wake up.
# Decoded sentence: Obudź się.
#
# -
# Input sentence: We lost.
# Decoded sentence: Przegraliśmy.
#
# -
# Input sentence: Welcome.
# Decoded sentence: Witamy.
