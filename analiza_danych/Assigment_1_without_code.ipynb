# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
#a)
#Your code:

df = pd.read_csv("kc_house_data.csv")
df.head()


#Hint: read_csv(), head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
#b) 
categorical_threshold = 100
for id in df.columns:
    print(id, len(df[id].unique()))


    
house_categorical_df = ["waterfront","zipcode"]
house_numerical_df = \
['id' ,
'date' ,
'price' ,
'bedrooms',
'bathrooms' ,
'sqft_living' ,
'sqft_lot' ,
'floors' ,
'waterfront' ,
'view' ,
'condition' ,
'grade' ,
'sqft_above' ,
'sqft_basement' ,
'yr_built' ,
'yr_renovated' ,
'lat' ,
'long' ,
'sqft_living15' ,
'sqft_lot15']
# Out:
# id 21436
# date 372
# price 4028
# bedrooms 13
# bathrooms 30
# sqft_living 1038
# sqft_lot 9782
# floors 6
# waterfront 2
# view 5
# condition 5
# grade 12
# sqft_above 946
# sqft_basement 306
# yr_built 116
# yr_renovated 70
# zipcode 70
# lat 5034
# long 752
# sqft_living15 777
# sqft_lot15 8689

# %%
#c)
#Your code:

df.describe()

#Hint: Function describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
#Your code:

plt.scatter(df.price,df.sqft_living)

#Hint plt.scatter

# %%
#b)
#Your code:
# ['id' ,'date' ,'price' ,'bedrooms','bathrooms' ,'sqft_living' ,'sqft_lot' ,'floors' ,'waterfront' ,'view' ,'condition' ,
# 'grade' ,'sqft_above' ,'sqft_basement' ,'yr_built' ,'yr_renovated' ,'lat' ,'long' ,'sqft_living15' ,'sqft_lot15']
plt.scatter(df.grade, df.price)
plt.show()
# plt.scatter(df.bedrooms,df.price)
# plt.show()
# plt.scatter(df.bathrooms,df.price)
# plt.show()
# plt.scatter(df.condition,df.price)
# plt.show()
# plt.scatter(df.sqft_living15,df.price)
# plt.show()

correlations = df.corr()
plt.matshow(correlations)
plt.show()
plt.bar(list(range(len(correlations.price))),correlations.price)
plt.xticks(list(range(len(correlations.price))),labels=correlations.columns,rotation=90)
plt.show()

# %%
#c)
#Your code:
plt.scatter(df.price,df.zipcode)

# %%
#Your code:
plt.scatter(df.long, df.lat, 0.3, df.price)
plt.show()
plt.scatter(df.long, df.lat, 0.3, df.sqft_living15)
plt.show()
plt.scatter(df.long, df.lat, 0.3, df.sqft_living)
plt.show()
plt.scatter(df.long, df.lat, 0.3, df.yr_built)
plt.show()
plt.scatter(df.long, df.lat, 0.3, df.grade)
plt.show()

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
#a)
#Your code:
plt.boxplot([df.price,df.grade])
#Hint: plt.boxplot
# Out:
# 0        7
# 1        7
# 2        6
# 3        7
# 4        8
#         ..
# 21608    8
# 21609    8
# 21610    7
# 21611    8
# 21612    7
# Name: grade, Length: 21613, dtype: int64

# %%
#b)
from statsmodels.graphics.mosaicplot import mosaic
# Wykres jest nieczytelny 
#Your code:
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-1a501e5ab15c> in <module>
#       1 #b)
# ----> 2 from statsmodels.graphics.mosaicplot import mosaic
#       3
#       4 #Your code:
#       5
#
# ModuleNotFoundError: No module named 'statsmodels'

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
#Your code:
selection = df[(df.bedrooms==3) & (df.bathrooms==2) & (df.floors==2)]
selection.describe()
#Hint: pandas.DataFrame.loc
# Out:
#                  id         price  bedrooms  bathrooms  sqft_living  \
# count  1.540000e+02  1.540000e+02     154.0      154.0   154.000000
# mean   4.397177e+09  5.144986e+05       3.0        2.0  1850.279221
# std    2.849813e+09  2.497661e+05       0.0        0.0   547.585413
# min    7.600057e+06  2.090000e+05       3.0        2.0  1020.000000
# 25%    2.060901e+09  3.769750e+05       3.0        2.0  1452.500000
# 50%    3.630010e+09  4.640000e+05       3.0        2.0  1700.000000
# 75%    7.184074e+09  5.894625e+05       3.0        2.0  2127.500000
# max    9.829200e+09  1.755000e+06       3.0        2.0  3650.000000
#
#             sqft_lot  floors  waterfront        view   condition       grade  \
# count     154.000000   154.0  154.000000  154.000000  154.000000  154.000000
# mean    23678.948052     2.0    0.006494    0.357143    3.435065    7.551948
# std     83324.024708     0.0    0.080582    0.919495    0.713322    0.832684
# ...

# %%
#b)
#Your code:
not_selected =df[(df.bedrooms!=3) & (df.bathrooms!=2) & (df.floors!=2)]
plt.scatter(df.long, df.lat, 0.2)
plt.scatter(selection.long, selection.lat, 2)

plt.show()

# %%
#c)
#Your code:
selection['price_foot_ratio'] = selection.price / selection.sqft_living
selection.sort_values('price_foot_ratio',ascending=True).iloc[0]
#Hint: .loc, .sort_values(), .index
# Out:
# /home/SoliareofAstora/miniconda3/envs/analiza/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# id                       7452500565
# date                20140829T000000
# price                        260000
# bedrooms                          3
# bathrooms                         2
# sqft_living                    2710
# sqft_lot                       5000
# floors                            2
# waterfront                        0
# view                              0
# condition                         3
# grade                             6
# sqft_above                     2710
# ...
